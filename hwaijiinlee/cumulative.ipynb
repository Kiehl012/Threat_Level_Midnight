# %%
import pandas as pd

# %%
test_df = pd.read_csv("../Data/cleaned_scripts.csv", index_col=0)
test_df.head(20)
# Out:
#    character                                               line  season  \
# 0    Michael  All right Jim. Your quarterlies look very good...       1
# 1        Jim         Oh, I told you. I couldn't close it. So...       1
# 2    Michael  So you've come to the master for guidance? Is ...       1
# 3        Jim         Actually, you called me in here, but yeah.       1
# 4    Michael    All right. Well, let me show you how it's done.       1
# 5    Michael                       So that's the way it's done.       1
# 6    Michael  I've, uh, I've been at Dunder Mifflin for 12 y...       1
# 7        Pam                                Well. I don't know.       1
# 8    Michael  If you think she's cute now, you should have s...       1
# 9        Pam                                              What?       1
# 10   Michael                                      Any messages?       1
# 11       Pam                              Uh, yeah. Just a fax.       1
# ...

# %%
test_df.loc[(test_df['character']=='Dwight') & (test_df['season']==1), 'character'].count()
# Out:
# 325

# %%
# create new Dataframe for total lines per character per season
total_lines_df = test_df.groupby(['season', 'character'])['character'].count().reset_index(name="lines_per_season")
total_lines_df
# Out:
#      season    character  lines_per_season
# 0         1       Angela                32
# 1         1       Darryl                17
# 2         1       Dwight               325
# 3         1          Jan                38
# 4         1          Jim               284
# ..      ...          ...               ...
# 196       9          Roy                11
# 197       9         Ryan                33
# 198       9      Stanley                96
# 199       9         Toby               122
# 200       9  Todd Packer                16
#
# [201 rows x 3 columns]

# %%
import datetime
# adding arbitrary year to each season
first_air_date = datetime.date(2003, 3, 24)
total_lines_df['arb_date'] = first_air_date
total_lines_df.head()
# Out:
#    season character  lines_per_season    arb_date
# 0       1    Angela                32  2003-03-24
# 1       1    Darryl                17  2003-03-24
# 2       1    Dwight               325  2003-03-24
# 3       1       Jan                38  2003-03-24
# 4       1       Jim               284  2003-03-24

# %%
total_lines_df['date'] = total_lines_df[['arb_date', 'season']].apply(lambda x: x['arb_date'] + 
                                                                  pd.DateOffset(years=x['season']), axis=1)
total_lines_df.head()
# Out:
#    season character  lines_per_season    arb_date       date  cumulative_lines
# 0       1    Angela                32  2003-03-24 2004-03-24                32
# 1       1    Darryl                17  2003-03-24 2004-03-24                17
# 2       1    Dwight               325  2003-03-24 2004-03-24               325
# 3       1       Jan                38  2003-03-24 2004-03-24                38
# 4       1       Jim               284  2003-03-24 2004-03-24               284

# %%
total_lines_df.tail()
# Out:
#      season    character  lines_per_season    arb_date       date
# 196       9          Roy                11  2003-03-24 2012-03-24
# 197       9         Ryan                33  2003-03-24 2012-03-24
# 198       9      Stanley                96  2003-03-24 2012-03-24
# 199       9         Toby               122  2003-03-24 2012-03-24
# 200       9  Todd Packer                16  2003-03-24 2012-03-24

# %%
# creating a cumulative lines column
total_lines_df['cumulative_lines'] = total_lines_df.groupby('character')['lines_per_season'].cumsum()
total_lines_df.head(25)
# Out:
#     season    character  ...       date cumulative_lines
# 0        1       Angela  ... 2004-03-24               32
# 1        1       Darryl  ... 2004-03-24               17
# 2        1       Dwight  ... 2004-03-24              325
# 3        1          Jan  ... 2004-03-24               38
# 4        1          Jim  ... 2004-03-24              284
# 5        1        Kelly  ... 2004-03-24                4
# 6        1        Kevin  ... 2004-03-24               29
# 7        1     Meredith  ... 2004-03-24               18
# 8        1      Michael  ... 2004-03-24              640
# 9        1        Oscar  ... 2004-03-24               58
# 10       1          Pam  ... 2004-03-24              215
# 11       1      Phyllis  ... 2004-03-24               11
# 12       1          Roy  ... 2004-03-24               35
# 13       1         Ryan  ... 2004-03-24               52
# 14       1      Stanley  ... 2004-03-24               27
# ...

# %%
# create new DataFrame for total lines per character per season
#total_lines2_df = pd.pivot_table(test_df, index=['season', 'character'], aggfunc={'character': len}).rename(columns={'character': 'total_lines'})
#total_lines2_df
# Out:
#                     total_lines
# season character
# 1      Angela                32
#        Darryl                17
#        Dwight               325
#        Jan                   38
#        Jim                  284
# ...                         ...
# 9      Roy                   11
#        Ryan                  33
#        Stanley               96
#        Toby                 122
#        Todd Packer           16
#
# [201 rows x 1 columns]
