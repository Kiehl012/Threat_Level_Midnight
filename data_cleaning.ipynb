# %%
import pandas as pd
import numpy as np
import re

# %%
file_path ='Data/Scripts.csv'
df = pd.read_csv(file_path,index_col=0)
df
# Out:
#       character                                               line  season  \
# 0       Michael  All right Jim. Your quarterlies look very good...     100
# 1           Jim         Oh, I told you. I couldn't close it. So...     100
# 2       Michael  So you've come to the master for guidance? Is ...     100
# 3           Jim         Actually, you called me in here, but yeah.     100
# 4       Michael    All right. Well, let me show you how it's done.     100
# ...         ...                                                ...     ...
# 60552     Creed  It all seems so very arbitrary. I applied for ...     900
# 60553  Meredith  I just feel lucky that I got a chance to share...     900
# 60554   Phyllis  I'm happy that this was all filmed so I can re...     900
# 60555       Jim  I sold paper at this company for 12 years. My ...     900
# 60556       Pam  I thought it was weird when you picked us to m...     900
#
#        episode  line_ID
# 0            1      101
# ...

# %%
# clear spaces at beginning and end of character names
df['character'] = df['character'].str.strip()

# %%
lines = df[['character','line']]
lines = lines.groupby(lines['character'],as_index=False).count()

# %%
lines = lines.sort_values('line', ascending=False)
lines.head(32)
# Out:
#          character   line
# 572        Michael  12085
# 307         Dwight   7504
# 455            Jim   6782
# 656            Pam   5348
# 108           Andy   3942
# 489          Kevin   1823
# 125         Angela   1757
# 645          Oscar   1548
# 335           Erin   1485
# 757           Ryan   1407
# 265         Darryl   1249
# 699        Phyllis   1070
# 480          Kelly    997
# 448            Jan    957
# 830           Toby    936
# 798        Stanley    766
# 560       Meredith    655
# 414          Holly    608
# 623         Nellie    529
# 247          Creed    456
# 369           Gabe    451
# 742         Robert    430
# 274          David    382
# 476          Karen    342
# 226          Clark    260
# 754            Roy    259
# 212        Charles    221
# 688           Pete    213
# 465             Jo    190
# 282       Deangelo    171
# 276  David Wallace    108
# 478           Katy     98

# %%
# check for mispellings or variations of 'Michael'
lines[lines['character'].str.startswith('Mich')]
# Out:
#                       character   line
# 572                     Michael  12085
# 588                    Michael:     74
# 580          Michael and Dwight     11
# 590                     Micheal      9
# 591                      Michel      5
# 574             Michael & Holly      4
# 573            Michael & Dwight      3
# 577       Michael and Christian      2
# 575          Michael [on phone]      2
# 571                      Michae      2
# 583             Michael and Jim      2
# 589                      Michal      1
# 587              Michael/Dwight      1
# 586         Michael, Pam & Ryan      1
# 585  Michael, Holly, and Darryl      1
# 584                Michael's Ad      1
# 582           Michael and Holly      1
# 581            Michael and Erin      1
# 579           Michael and Donna      1
# 578          Michael and Darryl      1
# 576            Michael and Andy      1

# %%
# clean names for 'Michael'
df['character'].replace({'Michael:':'Michael'}, inplace=True)
df['character'].replace({'Michel':'Michael'}, inplace=True)
df['character'].replace({'Micheal':'Michael'}, inplace=True)
df['character'].replace({'Michae':'Michael'}, inplace=True)
df['character'].replace({'Michal':'Michael'}, inplace=True)
df['character'].replace({'Michael [on phone]':'Michael'}, inplace=True)

# %%
# check for mispellings or variations of 'Dwight'
lines[lines['character'].str.startswith('Dwi')]
# Out:
#                      character  line
# 307                     Dwight  7504
# 320                    Dwight:    35
# 314         Dwight and Michael     6
# 321             DwightKSchrute     3
# 308              Dwight & Andy     2
# 311            Dwight and Andy     2
# 313            Dwight and Erin     2
# 319                    Dwight.     1
# 318    Dwight, Jim and Michael     1
# 317          Dwight, Jim & Pam     1
# 316  Dwight, Erin, Jim & Kevin     1
# 315             Dwight and Roy     1
# 312          Dwight and Angela     1
# 310          Dwight [on phone]     1
# 309              Dwight & Nate     1

# %%
df['character'].replace({'Dwight:':'Dwight'}, inplace=True)
df['character'].replace({'DwightKSchrute':'Dwight'}, inplace=True)
df['character'].replace({'Dwight.':'Dwight'}, inplace=True)
df['character'].replace({'Dwight [on phone]':'Dwight'}, inplace=True)

# %%
# check for mispellings or variations of 'Jim'
lines[lines['character'].str.startswith('Ji')]
# Out:
#                         character  line
# 455                           Jim  6782
# 464                          Jim:    33
# 459                   Jim and Pam     4
# 457                     Jim & Pam     2
# 456                  Jim & Dwight     2
# 463  Jim, Pam, Michael and Dwight     2
# 462         Jim, Josh, and Dwight     1
# 461               Jim's voicemail     1
# 460                     Jim's Dad     1
# 458                Jim and Dwight     1

# %%
df['character'].replace({'Jim:':'Jim'}, inplace=True)

# %%
# check for mispellings or variations of 'Pam'
lines[lines['character'].str.startswith('Pam')]
# Out:
#                           character  line
# 656                             Pam  5348
# 668                            Pam:    31
# 664                       Pam's Mom    18
# 666                       Pam's mom    11
# 658                  Pam [on phone]     4
# 662  Pam as "fourth-biggest client"     3
# 663   Pam as "ninth-biggest client"     2
# 659                     Pam and Jim     2
# 657                    Pam & Dwight     1
# 661                  Pam and others     1
# 660                   Pam and Kelly     1
# 665                       Pam's dad     1
# 667                         Pam/Jim     1

# %%
df['character'].replace({'Pam:':'Pam'}, inplace=True)
df['character'].replace({'Pam [on phone]':'Pam'}, inplace=True)
df['character'].replace({'Pam as "ninth-biggest client"':'Pam'}, inplace=True)
df['character'].replace({'Pam as "fourth-biggest client"':'Pam'}, inplace=True)

# %%
# check for mispellings or variations of 'Andy'
lines[lines['character'].str.startswith('And')]
# Out:
#                              character  line
# 108                               Andy  3942
# 123                              Andy:    35
# 117          Andy, Creed, Kevin, Kelly     5
# 113                    Andy and Dwight     5
# 115                       Andy and Jim     4
# 112                    Andy and Darryl     3
# 111                      Andy & Walter     3
# 110                     Andy & Michael     3
# 109                        Andy & Erin     3
# 122                       Andy/Stanley     1
# 121                           Andy/Pam     1
# 120                         Andy/Oscar     1
# 119       Andy, Darryl & Officer Foley     1
# 118  Andy, Creed, Kevin, Kelly, Darryl     1
# 116                   Andy and Michael     1
# 114                      Andy and Erin     1

# %%
df['character'].replace({'Andy:':'Andy'}, inplace=True)

# %%
# check for mispellings or variations of 'Kevin'
lines[lines['character'].str.startswith('Kev')]
# Out:
#             character  line
# 489             Kevin  1823
# 495            Kevin:     7
# 490      Kevin & Andy     1
# 494  Kevin's computer     1
# 493   Kevin and Oscar     1
# 492     Kevin & Oscar     1
# 491  Kevin & Meredith     1

# %%
df['character'].replace({'Kevin:':'Kevin'}, inplace=True)

# %%
# check for mispellings or variations of 'Angela'
lines[lines['character'].str.startswith('Ang')]
# Out:
#              character  line
# 125             Angela  1757
# 130            Angela:    17
# 126     Angela & Oscar     3
# 127  Angela and Dwight     1
# 124              Angel     1
# 128   Angela and Kelly     1
# 129         Angela/Pam     1
# 132             Anglea     1
# 131             Angels     1

# %%
df['character'].replace({'Angela:':'Angela'}, inplace=True)
df['character'].replace({'Angel':'Angela'}, inplace=True)
df['character'].replace({'Anglea':'Angela'}, inplace=True)
df['character'].replace({'Angels':'Angela'}, inplace=True)

# %%
# check for mispellings or variations of 'Oscar'
lines[lines['character'].str.startswith('Osc')]
# Out:
#                            character  line
# 645                            Oscar  1548
# 650                           Oscar:    20
# 648                   Oscar's friend     3
# 646                Oscar and Stanley     1
# 647                 Oscar's Computer     1
# 649  Oscar's voice from the computer     1

# %%
df['character'].replace({'Oscar:':'Oscar'}, inplace=True)

# %%
# check for mispellings or variations of 'Erin'
lines[lines['character'].str.startswith('Er')]
# Out:
#              character  line
# 335               Erin  1485
# 334               Eric    35
# 339              Erin:    16
# 340            Ernesto     4
# 338  Erin's Cell Phone     1
# 337     Erin and Kelly     1
# 336     Erin and Irene     1

# %%
df['character'].replace({'Erin:':'Erin'}, inplace=True)

# %%
# check for mispellings or variations of 'Ryan'
lines[lines['character'].str.startswith('Ry')]
# Out:
#             character  line
# 757              Ryan  1407
# 758       Ryan Howard    17
# 763             Ryan:     5
# 762  Ryan's Voicemail     1
# 761   Ryan and others     1
# 759    Ryan and Kelly     1
# 760  Ryan and Michael     1

# %%
df['character'].replace({'Ryan:':'Ryan'}, inplace=True)
df['character'].replace({'Ryan Howard':'Ryan'}, inplace=True)

# %%
# check for mispellings or variations of 'Darryl'
lines[lines['character'].str.startswith('Darr')]
# Out:
#              character  line
# 265             Darryl  1249
# 272            Darryl:    10
# 271    Darryl's sister     2
# 263             Darrly     2
# 270   Darryl and Kevin     1
# 269    Darryl and Katy     1
# 268  Darryl and Angela     1
# 267    Darryl and Andy     1
# 266     Darryl & Oscar     1
# 264              Darry     1

# %%
df['character'].replace({'Darryl:':'Darryl'}, inplace=True)
df['character'].replace({'Darry':'Darryl'}, inplace=True)
df['character'].replace({'Darrly':'Darryl'}, inplace=True)

# %%
# check for mispellings or variations of 'Phyllis'
lines[lines['character'].str.contains('phyl', case=False)]
# Out:
#                              character  line
# 699                            Phyllis  1070
# 704                           Phyllis:     6
# 697                             Phylis     2
# 799                  Stanley & Phyllis     1
# 698                            Phyliss     1
# 701           Phyllis, Kevin & Stanley     1
# 700                  Phyllis and Creed     1
# 702  Phyllis, Meredith, Michael, Kevin     1
# 703           Phyllis, Stanley, Dwight     1
# 55                           "Phyllis"     1

# %%
df['character'].replace({'Phyllis:':'Phyllis'}, inplace=True)
df['character'].replace({'Phylis':'Phyllis'}, inplace=True)
df['character'].replace({'Phyliss':'Phyllis'}, inplace=True)

# %%
# check for mispellings or variations of 'Kelly'
lines[lines['character'].str.contains('kell', case=False)]
# Out:
#                              character  line
# 480                              Kelly   997
# 295                        Diane Kelly    18
# 485                        Kelly's Mom     5
# 117          Andy, Creed, Kevin, Kelly     5
# 481                       Kelly & Erin     4
# 486                             Kelly:     4
# 484                     Kelly's Father     3
# 483                     Kelly and Erin     2
# 660                      Pam and Kelly     1
# 759                     Ryan and Kelly     1
# 118  Andy, Creed, Kevin, Kelly, Darryl     1
# 128                   Angela and Kelly     1
# 482              Kelly & Erin together     1
# 561                   Meredith & Kelly     1
# 370                    Gabe/Kelly/Toby     1
# 337                     Erin and Kelly     1

# %%
df['character'].replace({'Kelly:':'Kelly'}, inplace=True)

# %%
# check for mispellings or variations of 'Jan'
lines[lines['character'].str.contains('jan', case=False)]
# Out:
#           character  line
# 448             Jan   957
# 449  Jan [on phone]     1

# %%
df['character'].replace({'Jan [on phone]':'Jan'}, inplace=True)

# %%
# check for mispellings or variations of 'Toby'
lines[lines['character'].str.contains('Tob', case=False)]
# Out:
#            character  line
# 830             Toby   936
# 34    "Goodbye Toby"     1
# 370  Gabe/Kelly/Toby     1

# %%
# check for mispellings or variations of 'Stanley'
lines[lines['character'].str.contains('stan', case=False)]
# Out:
#                     character  line
# 798                   Stanley   766
# 797                   Stanely     2
# 800                  Stanley:     1
# 718      Production Assistant     1
# 646         Oscar and Stanley     1
# 799         Stanley & Phyllis     1
# 701  Phyllis, Kevin & Stanley     1
# 703  Phyllis, Stanley, Dwight     1
# 122              Andy/Stanley     1
# 626       New Instant Message     1
# 349              Fake Stanley     1

# %%
df['character'].replace({'Stanley:':'Stanley'}, inplace=True)
df['character'].replace({'Stanely':'Stanley'}, inplace=True)

# %%
# check for mispellings or variations of 'Meredith'
lines[lines['character'].str.contains('mere', case=False)]
# Out:
#                              character  line
# 560                           Meredith   655
# 562                     Meredith's Vet     3
# 702  Phyllis, Meredith, Michael, Kevin     1
# 491                   Kevin & Meredith     1
# 564                          Meredith:     1
# 563    Meredith, Creed, Oscar and Matt     1
# 561                   Meredith & Kelly     1

# %%
df['character'].replace({'Meridith':'Meredith'}, inplace=True)
df['character'].replace({'Meredith:':'Meredith'}, inplace=True)
df['character'].replace({'Meridith':'Meredith'}, inplace=True)

# %%
# check for mispellings or variations of 'Holly'
lines[lines['character'].str.contains('hol', case=False)]
# Out:
#                       character  line
# 414                       Holly   608
# 417                 Holly's Dad     5
# 418                 Holly's Mom     4
# 574             Michael & Holly     4
# 419                        Holy     2
# 786                 Shareholder     1
# 829           Third Shareholder     1
# 774          Second Shareholder     1
# 585  Michael, Holly, and Darryl     1
# 582           Michael and Holly     1
# 416             Holly & Michael     1
# 415              Holly & Darryl     1
# 362          Fourth Shareholder     1
# 355          Female Shareholder     1

# %%
df['character'].replace({'Holy':'Holly'}, inplace=True)

# %%
# check for mispellings or variations of 'Nellie'
lines[lines['character'].str.contains('Nell', case=False)]
# Out:
#           character  line
# 623          Nellie   529
# 625  Nellie and Pam     1
# 624  Nellie Bertram     1

# %%
df['character'].replace({'Nellie Bertram':'Nellie'}, inplace=True)

# %%
# check for mispellings or variations of 'Creed'
lines[lines['character'].str.contains('Cree', case=False)]
# Out:
#                              character  line
# 247                              Creed   456
# 117          Andy, Creed, Kevin, Kelly     5
# 733      Receptionitis15 [screen name]     1
# 743                     Robert & Creed     1
# 700                  Phyllis and Creed     1
# 638                          Offscreen     1
# 118  Andy, Creed, Kevin, Kelly, Darryl     1
# 442              JIM9334 [screen name]     1
# 248                             Creed:     1
# 563    Meredith, Creed, Oscar and Matt     1

# %%
df['character'].replace({'Creed:':'Creed'}, inplace=True)

# %%
# check for mispellings or variations of 'Gabe'
lines[lines['character'].str.contains('Gab', case=False)]
# Out:
#            character  line
# 369             Gabe   451
# 371            Gabor     3
# 370  Gabe/Kelly/Toby     1

# %%
# check for mispellings or variations of 'Robert'
lines[lines['character'].str.contains('Rob', case=False)]
# Out:
#              character  line
# 742             Robert   430
# 744  Robert California    15
# 180       Broccoli Rob    11
# 745      Robert Dunder    11
# 746      Robotic Voice     2
# 743     Robert & Creed     1

# %%
df['character'].replace({'Robert California':'Robert'}, inplace=True)

# %%
# check for mispellings or variations of 'David'
lines[lines['character'].str.contains('Dav', case=False)]
# Out:
#                      character  line
# 274                      David   382
# 276              David Wallace   108
# 613                 Mrs. Davis     5
# 275                David Brent     2
# 277  David Wallace's Secretary     2
# 278              David Wallcve     1

# %%
df['character'].replace({'David Wallace':'David'}, inplace=True)
df['character'].replace({'David Wallcve':'David'}, inplace=True)

# %%
# check for mispellings or variations of 'Karen'
lines[lines['character'].str.contains('Kar', case=False)]
# Out:
#     character  line
# 476     Karen   342

# %%
# check for mispellings or variations of 'Clark'
lines[lines['character'].str.contains('Cla', case=False)]
# Out:
#       character  line
# 226       Clark   260
# 227  Clay Aiken     2

# %%
# check for mispellings or variations of 'Roy'
lines[lines['character'].str.contains('Roy', case=False)]
# Out:
#           character  line
# 754             Roy   259
# 840            Troy    12
# 315  Dwight and Roy     1

# %%
# check for mispellings or variations of 'Charles'
lines[lines['character'].str.contains('Char', case=False)]
# Out:
#     character  line
# 212   Charles   221
# 211    Chares     1

# %%
df['character'].replace({'Chares':'Charles'}, inplace=True)

# %%
# check for mispellings or variations of 'Pete'
lines[lines['character'].str.contains('Pete', case=False)]
# Out:
#         character  line
# 688          Pete   213
# 836  Tom and Pete     1
# 689  Pete Halpert     1

# %%
# check for mispellings or variations of 'Jo'
lines[lines['character'].str.contains('Jo', case=False)]
# Out:
#                  character  line
# 465                     Jo   190
# 469                   Josh    64
# 468                 Jordan    13
# 467                   Joan     5
# 42                    "Jo"     4
# 865             W.B. Jones     4
# 75               "The Job"     1
# 43              "Job Fair"     1
# 466             Jo Bennett     1
# 462  Jim, Josh, and Dwight     1

# %%
df['character'].replace({'Jo Bennett':'Jo'}, inplace=True)

# %%
# check for mispellings or variations of 'Deangelo'
lines[lines['character'].str.contains('Dea', case=False)]
# Out:
#                 character  line
# 282              Deangelo   171
# 280              DeAngelo    79
# 281                Dealer     5
# 283      Deangelo/Michael     2
# 862  Voice of Thomas Dean     1
# 206            Casey Dean     1
# 279              DeAgnelo     1

# %%
df['character'].replace({'DeAngelo':'Deangelo'}, inplace=True)
df['character'].replace({'DeAgnelo':'Deangelo'}, inplace=True)
df['character'].replace({'Denagelo':'Deangelo'}, inplace=True)

# %%
# check for mispellings or variations of 'Katy'
lines[lines['character'].str.contains('Kat', case=False)]
# Out:
#            character  line
# 478             Katy    98
# 477            Kathy    10
# 269  Darryl and Katy     1

# %%
# check for mispellings or variations of 'Carol'
lines[lines['character'].str.contains('Car', case=False)]
# Out:
#                            character  line
# 645                            Oscar  1548
# 201                            Carol    90
# 650                           Oscar:    20
# 204                          Carroll    14
# 199                            Carla    10
# 200                       Carla Fern     5
# 648                   Oscar's friend     3
# 126                   Angela & Oscar     3
# 646                Oscar and Stanley     1
# 647                 Oscar's Computer     1
# 649  Oscar's voice from the computer     1
# 120                       Andy/Oscar     1
# 102                    All but Oscar     1
# 202                     Carol Stills     1
# 203                           Carrol     1
# 65                      "The Carpet"     1
# 37                     "Health Care"     1
# 246                  Credit card rep     1
# 493                  Kevin and Oscar     1
# 492                    Kevin & Oscar     1
# 563  Meredith, Creed, Oscar and Matt     1
# ...

# %%
df['character'].replace({'Carroll':'Carol'}, inplace=True)
df['character'].replace({'Carrol':'Carol'}, inplace=True)

# %%
# check for mispellings or variations of 'Donna'
lines[lines['character'].str.contains('Don', case=False)]
# Out:
#              character  line
# 300              Donna    81
# 177            Brandon    18
# 301      Donna Muraski     2
# 579  Michael and Donna     1

# %%
# check for mispellings or variations of 'Todd Packer'
lines[lines['character'].str.contains('tod', case=False)]
# Out:
#         character  line
# 832   Todd Packer    75
# 831          Todd    40
# 817  Sweeney Todd    14

# %%
df['character'].replace({'Todd':'Todd Packer'}, inplace=True)

# %%
lines = df[['character','line']]
lines = lines.groupby(lines['character'],as_index=False).count()

# %%
lines = lines.sort_values('line', ascending=False)
lines.head()
# Out:
#     character   line
# 541   Michael  12178
# 290    Dwight   7544
# 431       Jim   6815
# 618       Pam   5388
# 108      Andy   3977

# %%
# Find Characters with >100 lines and create new df that includes only those characters
character_list = lines.query('line>100')['character'].to_list()
new_df = df[df['character'].isin(character_list)]
new_df
# Out:
#       character                                               line  season  \
# 0       Michael  All right Jim. Your quarterlies look very good...     100
# 1           Jim         Oh, I told you. I couldn't close it. So...     100
# 2       Michael  So you've come to the master for guidance? Is ...     100
# 3           Jim         Actually, you called me in here, but yeah.     100
# 4       Michael    All right. Well, let me show you how it's done.     100
# ...         ...                                                ...     ...
# 60552     Creed  It all seems so very arbitrary. I applied for ...     900
# 60553  Meredith  I just feel lucky that I got a chance to share...     900
# 60554   Phyllis  I'm happy that this was all filmed so I can re...     900
# 60555       Jim  I sold paper at this company for 12 years. My ...     900
# 60556       Pam  I thought it was weird when you picked us to m...     900
#
#        episode  line_ID
# 0            1      101
# ...

# %%
# Check df for stage directions and other non-script text as defined by text inside of square brackets '[]'
len(new_df[new_df['line'].str.contains('\]|\[')])
# Out:
# 9456

# %%
# Removed stage directions and other non-script text as defined by text instead of square brackets '[]'
new_df['line'] = new_df['line'].str.replace(r"\[[^()]*\]", "", regex=True)
len(new_df[new_df['line'].str.contains('\]|\[')])
# Out:
# C:\Users\kbrad\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 18

# %%
# Convert blank lines to NaN and remove rows with NaN values.
new_df['line'] = new_df['line'].str.strip()
new_df = new_df.replace('', np.NaN, regex=False)
new_df = new_df.dropna()
# Out:
# C:\Users\kbrad\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# export new_df to csv file
#new_df.to_csv('./cleaned_scripts.csv')

# %%
# export new_df to JSON file
# new_df.to_json('./cleaned_scripts.JSON', orient='columns')

# %%
len(new_df)
# Out:
# 55029

# %%
line = new_df['line'].tolist()

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
line_scores = []
for sentence in line:
    score = analyser.polarity_scores(sentence)
    line_scores.append(score)
#Converting List of Dictionaries into Dataframe
lineScore_df= pd.DataFrame(line_scores)
lineScore_df.head(20)
# Out:
#       neg    neu    pos  compound
# 0   0.000  0.803  0.197    0.4927
# 1   0.000  1.000  0.000    0.0000
# 2   0.000  1.000  0.000    0.0000
# 3   0.000  0.714  0.286    0.4215
# 4   0.000  0.811  0.189    0.2732
# 5   0.000  1.000  0.000    0.0000
# 6   0.000  0.969  0.031    0.2225
# 7   0.000  0.588  0.412    0.2732
# 8   0.000  0.833  0.167    0.4588
# 9   0.000  1.000  0.000    0.0000
# 10  0.000  1.000  0.000    0.0000
# 11  0.000  0.645  0.355    0.2960
# 12  0.000  0.875  0.125    0.4574
# 13  0.000  1.000  0.000    0.0000
# 14  0.000  1.000  0.000    0.0000
# 15  0.000  0.662  0.338    0.9578
# 16  0.087  0.913  0.000   -0.4019
# 17  0.000  1.000  0.000    0.0000
# 18  0.000  0.609  0.391    0.6696
# 19  0.000  1.000  0.000    0.0000

# %%
sentiment = lineScore_df['compound'].tolist()

# %%
new_df['sentiment_score'] = sentiment
new_df.head(20)
# Out:
#    character                                               line  season  \
# 0    Michael  All right Jim. Your quarterlies look very good...     100
# 1        Jim         Oh, I told you. I couldn't close it. So...     100
# 2    Michael  So you've come to the master for guidance? Is ...     100
# 3        Jim         Actually, you called me in here, but yeah.     100
# 4    Michael    All right. Well, let me show you how it's done.     100
# 5    Michael                       So that's the way it's done.     100
# 6    Michael  I've, uh, I've been at Dunder Mifflin for 12 y...     100
# 7        Pam                                Well. I don't know.     100
# 8    Michael  If you think she's cute now, you should have s...     100
# 9        Pam                                              What?     100
# 10   Michael                                      Any messages?     100
# 11       Pam                              Uh, yeah. Just a fax.     100
# ...

# %%
# export new_df to csv file
new_df.to_csv('Data/cleaned_scripts.csv')

# %%
cleanline = new_df['line'].tolist()

# %%
from spellchecker import SpellChecker

spell = SpellChecker() #loads default word frequency list

# %%
# find those words that may be misspelled
misspelled = spell.unknown(cleanline)

for word in misspelled:
    # Get the one `most likely` answer
    print(spell.correction(word))

    # Get a list of `likely` options
    print(spell.candidates(word))
# Out:
# no, that's him.
# {"no, that's him."}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-b061dafad375> in <module>
#       4 for word in misspelled:
#       5     # Get the one `most likely` answer
# ----> 6     print(spell.correction(word))
#       7
#       8     # Get a list of `likely` options
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spellchecker\spellchecker.py in correction(self, word)
#     181             str: The most likely candidate"""
#     182         word = ensure_unicode(word)
# --> 183         candidates = list(self.candidates(word))
#     184         return max(sorted(candidates), key=self.__getitem__)
#     185
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spellchecker\spellchecker.py in candidates(self, word)
#     206         # if still not found, use the edit distance 1 to calc edit distance 2
# ...
